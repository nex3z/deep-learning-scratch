# %%
import sys
import os
sys.path.append(os.path.join(os.curdir, os.pardir, os.pardir))

# %%
import numpy as np
import matplotlib.pyplot as plt
from data.mnist import read_data
from net.Model import Model
from common.layer import Dense, Relu, BatchNorm, SoftmaxWithLoss
from optimizer.GradientDescent import GradientDescent

# %%
model = Model()
model.add(Dense(784, 50))
model.add(BatchNorm(50))
model.add(Relu())
model.add(Dense(50, 10))
model.add(BatchNorm(10))
model.build(SoftmaxWithLoss(), optimizer=GradientDescent(learning_rate=0.1))

print(model.network.layers)
print(model.network.layers_cnt)
# Out:
# OrderedDict([('Dense_1', <common.layer.Dense object at 0x1068c6f98>), ('BatchNorm_1', <common.layer.BatchNorm object at 0x1068cd0b8>), ('Relu_1', <common.layer.Relu object at 0x1068cd160>), ('Dense_2', <common.layer.Dense object at 0x1068cd198>), ('BatchNorm_2', <common.layer.BatchNorm object at 0x1068cd208>)])
# {'Dense': 2, 'BatchNorm': 2, 'Relu': 1}

# %%
data_set = read_data(base_dir='../../mnist_data', one_hot=True)
# Out:
# reading ../../mnist_data/train-images-idx3-ubyte.gz
# reading ../../mnist_data/t10k-images-idx3-ubyte.gz
# reading ../../mnist_data/train-labels-idx1-ubyte.gz
# reading ../../mnist_data/t10k-labels-idx1-ubyte.gz

# %%
data_set.train.images.shape
# Out:
# (55000, 784)

# %%
model.fit(data_set.train.images, data_set.train.labels, 
          batch_size=100, epochs=10, 
          validation_data=(data_set.test.images, data_set.test.labels))
# Out:
# Epoch 1/11
# Iter: 550, train_loss = 0.1613, train_acc = 0.9622, val_loss = 0.1666, val_acc = 0.9589
# Epoch 2/11
# Iter: 1100, train_loss = 0.1027, train_acc = 0.9756, val_loss = 0.1153, val_acc = 0.9690
# Epoch 3/11
# Iter: 1650, train_loss = 0.0892, train_acc = 0.9781, val_loss = 0.1055, val_acc = 0.9726
# Epoch 4/11
# Iter: 2200, train_loss = 0.0788, train_acc = 0.9800, val_loss = 0.1053, val_acc = 0.9695
# Epoch 5/11
# Iter: 2750, train_loss = 0.0664, train_acc = 0.9837, val_loss = 0.0951, val_acc = 0.9717
# Epoch 6/11
# Iter: 3300, train_loss = 0.0545, train_acc = 0.9876, val_loss = 0.0895, val_acc = 0.9748
# Epoch 7/11
# Iter: 3850, train_loss = 0.0498, train_acc = 0.9875, val_loss = 0.0863, val_acc = 0.9739
# Epoch 8/11
# Iter: 4400, train_loss = 0.0460, train_acc = 0.9891, val_loss = 0.0885, val_acc = 0.9751
# Epoch 9/11
# Iter: 4950, train_loss = 0.0417, train_acc = 0.9901, val_loss = 0.0835, val_acc = 0.9745
# Epoch 10/11
# Iter: 5500, train_loss = 0.0368, train_acc = 0.9920, val_loss = 0.0785, val_acc = 0.9767

# %%
model.plot_history(metric='loss')

# %%
model.plot_history(metric='accuracy')

# %%
np.mean([1,2,3])
# Out:
# 2.0

# %%
np.array([1,2,3]).mean()
# Out:
# 2.0
